# %% [markdown]
# # Testando um modelo simples de aprendizado de um Datase aleatório

# %% [markdown]
# ## Imports

# %%
import IPython.display as ipd
import json
import numpy as np
import matplotlib.pyplot as plt
import random
import soundfile as sf
import pandas as pd

from fm_synth import FMSynth, SAMPLE_RATE

# %% [markdown]
# ## Carregando o dataset

# %%
tamanho_dataset = 1000

# %%
samples = []
for i in range(tamanho_dataset):
    signal = sf.read(f"dataset/sample_{i}.wav")
    samples.append(signal)

samples = pd.DataFrame(samples)

# %%
samples = samples.drop(columns=[1])
samples.head()
# Out:
#                                                    0
# 0  [0.0, -0.000823974609375, -0.001495361328125, ...
# 1  [0.0, 6.103515625e-05, -0.000335693359375, 0.0...
# 2  [0.0, -0.000640869140625, -0.00189208984375, 0...
# 3  [0.0, 0.000518798828125, -0.000762939453125, -...
# 4  [0.0, 0.00018310546875, 0.0003662109375, 3.051...

# %% [markdown]
# ### Lendo o alvo

# %%
with open("dataset/parameters.json", "r") as f:
    target = f.read()

target = json.loads(target)
target = target[:tamanho_dataset]

target = pd.DataFrame(target)
target.head()
# Out:
#    id  frequencia_base  amplitude1  frequency1  beta2  amplitude2  frequency2  \
# 0   0        18209.492       0.364       0.490  0.204       0.192       0.715
# 1   1         9383.727       0.441       0.797  0.376       0.110       0.907
# 2   2        17779.337       0.845       0.884  0.549       0.063       0.866
# 3   3         6646.624       0.714       0.934  0.246       0.036       0.556
# 4   4         3602.038       0.103       0.625  0.311       0.795       0.871
#
#    beta3  amplitude3  frequency3  ...  frequency4  beta5  amplitude5  \
# 0  0.384       0.289       0.087  ...       0.410  0.173       0.568
# 1  0.510       0.544       0.366  ...       0.317  0.147       0.074
# 2  0.798       0.834       0.928  ...       0.475  0.229       0.950
# 3  0.652       0.534       0.779  ...       0.576  0.739       0.418
# 4  0.143       0.270       0.333  ...       0.128  0.131       0.011
#
#    frequency5  beta_carrier  amplitude_carrier  attack  decay  sustain  \
# 0       0.360         0.118              0.308   0.015  0.023    0.013
# 1       0.999         0.852              0.189   0.046  0.072    0.078
# 2       0.256         0.624              0.117   0.005  0.006    0.022
# 3       0.075         0.540              0.970   0.078  0.040    0.475
# 4       0.994         0.342              0.331   0.067  0.040    0.458
#
#    release
# 0    0.021
# 1    0.050
# 2    0.121
# 3    0.059
# 4    0.105
#
# [5 rows x 22 columns]

# %%
target = target.drop(columns=["id"])
target.head()
# Out:
#    frequencia_base  amplitude1  frequency1  beta2  amplitude2  frequency2  \
# 0        18209.492       0.364       0.490  0.204       0.192       0.715
# 1         9383.727       0.441       0.797  0.376       0.110       0.907
# 2        17779.337       0.845       0.884  0.549       0.063       0.866
# 3         6646.624       0.714       0.934  0.246       0.036       0.556
# 4         3602.038       0.103       0.625  0.311       0.795       0.871
#
#    beta3  amplitude3  frequency3  beta4  ...  frequency4  beta5  amplitude5  \
# 0  0.384       0.289       0.087  0.645  ...       0.410  0.173       0.568
# 1  0.510       0.544       0.366  0.936  ...       0.317  0.147       0.074
# 2  0.798       0.834       0.928  0.830  ...       0.475  0.229       0.950
# 3  0.652       0.534       0.779  0.802  ...       0.576  0.739       0.418
# 4  0.143       0.270       0.333  0.739  ...       0.128  0.131       0.011
#
#    frequency5  beta_carrier  amplitude_carrier  attack  decay  sustain  \
# 0       0.360         0.118              0.308   0.015  0.023    0.013
# 1       0.999         0.852              0.189   0.046  0.072    0.078
# 2       0.256         0.624              0.117   0.005  0.006    0.022
# 3       0.075         0.540              0.970   0.078  0.040    0.475
# 4       0.994         0.342              0.331   0.067  0.040    0.458
#
#    release
# 0    0.021
# 1    0.050
# 2    0.121
# 3    0.059
# 4    0.105
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Juntando alvo e features

# %%
ds = pd.concat([samples, target], axis=1)
ds.head()
# Out:
#                                                    0  frequencia_base  \
# 0  [0.0, -0.000823974609375, -0.001495361328125, ...        18209.492
# 1  [0.0, 6.103515625e-05, -0.000335693359375, 0.0...         9383.727
# 2  [0.0, -0.000640869140625, -0.00189208984375, 0...        17779.337
# 3  [0.0, 0.000518798828125, -0.000762939453125, -...         6646.624
# 4  [0.0, 0.00018310546875, 0.0003662109375, 3.051...         3602.038
#
#    amplitude1  frequency1  beta2  amplitude2  frequency2  beta3  amplitude3  \
# 0       0.364       0.490  0.204       0.192       0.715  0.384       0.289
# 1       0.441       0.797  0.376       0.110       0.907  0.510       0.544
# 2       0.845       0.884  0.549       0.063       0.866  0.798       0.834
# 3       0.714       0.934  0.246       0.036       0.556  0.652       0.534
# 4       0.103       0.625  0.311       0.795       0.871  0.143       0.270
#
#    frequency3  ...  frequency4  beta5  amplitude5  frequency5  beta_carrier  \
# 0       0.087  ...       0.410  0.173       0.568       0.360         0.118
# 1       0.366  ...       0.317  0.147       0.074       0.999         0.852
# 2       0.928  ...       0.475  0.229       0.950       0.256         0.624
# 3       0.779  ...       0.576  0.739       0.418       0.075         0.540
# 4       0.333  ...       0.128  0.131       0.011       0.994         0.342
#
#    amplitude_carrier  attack  decay  sustain  release
# 0              0.308   0.015  0.023    0.013    0.021
# 1              0.189   0.046  0.072    0.078    0.050
# 2              0.117   0.005  0.006    0.022    0.121
# 3              0.970   0.078  0.040    0.475    0.059
# 4              0.331   0.067  0.040    0.458    0.105
#
# [5 rows x 22 columns]

# %%
ds.shape
# Out:
# (1000, 22)

# %% [markdown]
# ## Separando treino e teste

# %%
train = ds.sample(frac=0.75, random_state=0)
test = ds.drop(train.index)

# %%
train.head(5)
# Out:
#                                                      0  frequencia_base  \
# 993  [0.0, -0.000152587890625, -0.00042724609375, -...        19347.502
# 859  [0.0, -0.00030517578125, -0.000732421875, -0.0...        18729.342
# 298  [0.0, -0.00067138671875, -0.000823974609375, 0...        17795.401
# 553  [0.0, -3.0517578125e-05, -6.103515625e-05, -3....        18426.567
# 672  [0.0, 0.0, 3.0517578125e-05, 3.0517578125e-05,...         2052.557
#
#      amplitude1  frequency1  beta2  amplitude2  frequency2  beta3  amplitude3  \
# 993       0.580       0.677  0.172       0.176       0.026  0.518       0.142
# 859       0.206       0.422  0.799       0.796       0.455  0.762       0.821
# 298       0.924       0.533  0.282       0.289       0.690  0.622       0.788
# 553       0.897       0.285  0.550       0.808       0.440  0.526       0.513
# 672       0.004       0.545  0.949       0.711       0.755  0.662       0.562
#
#      frequency3  ...  frequency4  beta5  amplitude5  frequency5  beta_carrier  \
# 993       0.155  ...       0.310  0.600       0.313       0.490         0.536
# 859       0.160  ...       0.258  0.299       0.578       0.437         0.061
# 298       0.792  ...       0.041  0.620       0.728       0.420         0.194
# 553       0.681  ...       0.663  0.883       0.495       0.430         0.790
# 672       0.722  ...       0.179  0.013       0.815       0.154         0.925
#
#      amplitude_carrier  attack  decay  sustain  release
# 993              0.853   0.188  0.023    0.121    0.130
# 859              0.635   0.076  0.024    0.354    0.189
# 298              0.808   0.049  0.080    0.236    0.150
# 553              0.125   0.127  0.073    0.341    0.069
# 672              0.023   0.062  0.056    0.161    0.193
#
# [5 rows x 22 columns]

# %%
x = pd.DataFrame(train[0])
x.head()
# Out:
#                                                      0
# 993  [0.0, -0.000152587890625, -0.00042724609375, -...
# 859  [0.0, -0.00030517578125, -0.000732421875, -0.0...
# 298  [0.0, -0.00067138671875, -0.000823974609375, 0...
# 553  [0.0, -3.0517578125e-05, -6.103515625e-05, -3....
# 672  [0.0, 0.0, 3.0517578125e-05, 3.0517578125e-05,...

# %%
x = np.array(x[0].values.tolist())
x[0]
# Out:
# array([ 0.00000000e+00, -1.52587891e-04, -4.27246094e-04, ...,
#        -9.15527344e-05, -9.15527344e-05, -3.05175781e-05])

# %%
len(x[0])
# Out:
# 22050

# %%
y = train.drop(columns=[0])
y.head()
# Out:
#      frequencia_base  amplitude1  frequency1  beta2  amplitude2  frequency2  \
# 993        19347.502       0.580       0.677  0.172       0.176       0.026
# 859        18729.342       0.206       0.422  0.799       0.796       0.455
# 298        17795.401       0.924       0.533  0.282       0.289       0.690
# 553        18426.567       0.897       0.285  0.550       0.808       0.440
# 672         2052.557       0.004       0.545  0.949       0.711       0.755
#
#      beta3  amplitude3  frequency3  beta4  ...  frequency4  beta5  amplitude5  \
# 993  0.518       0.142       0.155  0.811  ...       0.310  0.600       0.313
# 859  0.762       0.821       0.160  0.064  ...       0.258  0.299       0.578
# 298  0.622       0.788       0.792  0.111  ...       0.041  0.620       0.728
# 553  0.526       0.513       0.681  0.439  ...       0.663  0.883       0.495
# 672  0.662       0.562       0.722  0.950  ...       0.179  0.013       0.815
#
#      frequency5  beta_carrier  amplitude_carrier  attack  decay  sustain  \
# 993       0.490         0.536              0.853   0.188  0.023    0.121
# 859       0.437         0.061              0.635   0.076  0.024    0.354
# 298       0.420         0.194              0.808   0.049  0.080    0.236
# 553       0.430         0.790              0.125   0.127  0.073    0.341
# 672       0.154         0.925              0.023   0.062  0.056    0.161
#
#      release
# 993    0.130
# 859    0.189
# 298    0.150
# 553    0.069
# 672    0.193
#
# [5 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler_y = StandardScaler()
y_train_norm = scaler_y.fit_transform(y)
print(y_train_norm)
# Out:
# [[ 1.55769312  0.24406094  0.65910292 ... -0.93992134 -0.88790927
#    0.57783482]
#  [ 1.45289775 -1.05873069 -0.2290101  ... -0.90592042  0.71938899
#    1.60092983]
#  [ 1.29456868  1.44235057  0.15758027 ...  0.99813091 -0.09460755
#    0.92464669]
#  ...
#  [-0.39493883  0.39384715  1.01086533 ... -1.55193784 -0.54989375
#   -0.68802851]
#  [ 0.0523075   1.13581136  0.53023946 ...  0.86212724  0.00886658
#    1.06337143]
#  [-0.30275345 -1.6509087  -1.41316079 ...  0.89612816  0.41586486
#    0.0922982 ]]

# %% [markdown]
# ### Redimensionando a entrada

# %%
print(x.shape)
x = x.reshape((x.shape[0], x.shape[1], 1))
print(x.shape)

print(x[0])

# frame_length = 2048

# dataset = []
# for sample in x:
#   length = sample.shape[0]
#   num_frames = int(length / frame_length)
#   amostras_uteis = num_frames * frame_length
#   sample_cutted = sample[:amostras_uteis]
#   sample_cutted = sample_cutted.reshape(num_frames, frame_length)
#   dataset.append(sample_cutted)

# x = np.array(dataset)
# print(x.shape)
# x[0:5]
# Out:
# (750, 22050)
# (750, 22050, 1)
# [[ 0.00000000e+00]
#  [-1.52587891e-04]
#  [-4.27246094e-04]
#  ...
#  [-9.15527344e-05]
#  [-9.15527344e-05]
#  [-3.05175781e-05]]

# %% [markdown]
# ## Construindo o modelo

# %%
from keras.layers import TimeDistributed, Dense, Input, Lambda, BatchNormalization, Concatenate, Conv1D, ZeroPadding1D, Flatten, Dropout, MaxPooling1D
from keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.callbacks import EarlyStopping
import tensorflow as tf
# Out:
# 2025-02-26 20:16:04.388319: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-26 20:16:04.534615: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740611764.606843  130078 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740611764.625432  130078 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-26 20:16:04.776281: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Configurando para não alocar diretamente toda a memória da GPU (alocar conforme necessário)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)  # Aloca memória conforme necessário
    except RuntimeError as e:
        print(e)

# %%
def regressor(input_dims, output_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims/2), activation=activation, use_bias=bias, kernel_regularizer="l2")(input_layer)
  x_0 = Dropout(0.2)(x_0)
  x_2 = Dense(int(input_dims/4), activation=activation, use_bias=bias)(x_0)
  saidas = Dense(output_dims, activation=None, name='regressor_saidas', use_bias=bias)(x_2)

  return Model(input_layer, saidas, name="regressor")

def build_models(input_len, input_dims, output_dims, activation, bias):
  
  # Camadas de entrada
  input_layer = Input(shape=(input_len, input_dims))

  x_n = BatchNormalization()(input_layer)

  # Features 1
  extrator1 = Conv1D(
    filters=16,
    kernel_size=5,
    strides=2,
    activation='relu',
    input_shape=(input_len, 1),
    kernel_regularizer="l1",
    use_bias=True,
  )
  pooling1 = MaxPooling1D(pool_size=2)

  features1 = extrator1(x_n)
  features1 = pooling1(features1)

  features1 = Dropout(0.2)(features1)

  extrator1_2 = Conv1D(
    filters=32,
    kernel_size=128,
    strides=16,
    activation='relu',
    input_shape=(input_len, 1),
    kernel_regularizer="l2",
    use_bias=True,
  )
  pooling1_2 = MaxPooling1D(pool_size=32)

  features1_2 = extrator1_2(features1)
  features1_2 = pooling1_2(features1_2)

  # extrator1_3 = Conv1D(
  #   filters=64,
  #   kernel_size=512,
  #   strides=32,
  #   activation='relu',
  #   input_shape=(input_len, 1),
  #   kernel_regularizer="l2",
  #   use_bias=True,
  # )
  # pooling1_3 = MaxPooling1D(pool_size=128)

  # features1_3 = extrator1_3(features1_2)
  # features1_3 = pooling1_3(features1_3)

  features1_flatten1 = Flatten()(features1_2)

  # Regrssão
  regressao = regressor(features1_flatten1.shape[1], output_dims, activation, bias)

  saida = regressao(features1_flatten1)
  
  return (
      Model(input_layer, saida, name="regressao"),
      Model(input_layer, features1_flatten1, name="projecao")
  )

model, features = build_models(x.shape[1], x.shape[2], y_train_norm.shape[1], 'relu', False)
# model, features = build_models(x.shape[1], x.shape[2], y.shape[1], 'relu', False)
model.compile(optimizer='adamax', loss='mse', metrics=['mae', 'mse', 'mean_absolute_percentage_error'])
plot_model(model, show_shapes=True, expand_nested=True)
# Out:
# /home/sergiosilva/@pessoal/fmsynth/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Callback para recuperar o melhor peso, e parar quando ficar três épocas sem melhora
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# Treinando o modelo
history = model.fit(x, y_train_norm, epochs=150, validation_split = 0.2, callbacks=[callback])
# Out:
# Epoch 1/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 231ms/step - loss: 3.3932 - mae: 0.8909 - mean_absolute_percentage_error: 160.9154 - mse: 1.0791 - val_loss: 2.9739 - val_mae: 0.8611 - val_mean_absolute_percentage_error: 100.5577 - val_mse: 1.0007
# Epoch 2/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.8723 - mae: 0.8628 - mean_absolute_percentage_error: 117.9291 - mse: 0.9936 - val_loss: 2.6241 - val_mae: 0.8587 - val_mean_absolute_percentage_error: 101.7617 - val_mse: 0.9957
# Epoch 3/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.5351 - mae: 0.8515 - mean_absolute_percentage_error: 124.8643 - mse: 0.9734 - val_loss: 2.3699 - val_mae: 0.8567 - val_mean_absolute_percentage_error: 101.6161 - val_mse: 0.9915
# Epoch 4/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.2914 - mae: 0.8446 - mean_absolute_percentage_error: 136.0322 - mse: 0.9662 - val_loss: 2.1794 - val_mae: 0.8544 - val_mean_absolute_percentage_error: 102.8287 - val_mse: 0.9871
# Epoch 5/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1050 - mae: 0.8356 - mean_absolute_percentage_error: 122.9017 - mse: 0.9512 - val_loss: 2.0331 - val_mae: 0.8527 - val_mean_absolute_percentage_error: 103.8207 - val_mse: 0.9839
# Epoch 6/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9539 - mae: 0.8291 - mean_absolute_percentage_error: 127.3057 - mse: 0.9358 - val_loss: 1.9171 - val_mae: 0.8516 - val_mean_absolute_percentage_error: 104.0533 - val_mse: 0.9820
# Epoch 7/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.8453 - mae: 0.8275 - mean_absolute_percentage_error: 132.4318 - mse: 0.9375 - val_loss: 1.8195 - val_mae: 0.8490 - val_mean_absolute_percentage_error: 104.8337 - val_mse: 0.9774
# Epoch 8/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.7589 - mae: 0.8291 - mean_absolute_percentage_error: 125.3503 - mse: 0.9376 - val_loss: 1.7392 - val_mae: 0.8477 - val_mean_absolute_percentage_error: 106.4158 - val_mse: 0.9750
# Epoch 9/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.6735 - mae: 0.8250 - mean_absolute_percentage_error: 143.7673 - mse: 0.9287 - val_loss: 1.6682 - val_mae: 0.8451 - val_mean_absolute_percentage_error: 107.1733 - val_mse: 0.9702
# Epoch 10/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6084 - mae: 0.8224 - mean_absolute_percentage_error: 124.5314 - mse: 0.9261 - val_loss: 1.6090 - val_mae: 0.8437 - val_mean_absolute_percentage_error: 107.7143 - val_mse: 0.9683
# Epoch 11/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.5651 - mae: 0.8298 - mean_absolute_percentage_error: 128.1278 - mse: 0.9386 - val_loss: 1.5548 - val_mae: 0.8412 - val_mean_absolute_percentage_error: 108.6309 - val_mse: 0.9643
# Epoch 12/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.5108 - mae: 0.8260 - mean_absolute_percentage_error: 127.3975 - mse: 0.9324 - val_loss: 1.5064 - val_mae: 0.8384 - val_mean_absolute_percentage_error: 107.9275 - val_mse: 0.9602
# Epoch 13/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.4613 - mae: 0.8217 - mean_absolute_percentage_error: 128.0937 - mse: 0.9260 - val_loss: 1.4641 - val_mae: 0.8371 - val_mean_absolute_percentage_error: 109.3456 - val_mse: 0.9576
# Epoch 14/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.4232 - mae: 0.8225 - mean_absolute_percentage_error: 152.2559 - mse: 0.9270 - val_loss: 1.4231 - val_mae: 0.8339 - val_mean_absolute_percentage_error: 109.4313 - val_mse: 0.9523
# Epoch 15/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3800 - mae: 0.8184 - mean_absolute_percentage_error: 125.5826 - mse: 0.9178 - val_loss: 1.3877 - val_mae: 0.8319 - val_mean_absolute_percentage_error: 112.5055 - val_mse: 0.9492
# Epoch 16/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3471 - mae: 0.8163 - mean_absolute_percentage_error: 132.1490 - mse: 0.9173 - val_loss: 1.3583 - val_mae: 0.8321 - val_mean_absolute_percentage_error: 110.5447 - val_mse: 0.9492
# Epoch 17/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.3238 - mae: 0.8216 - mean_absolute_percentage_error: 120.1473 - mse: 0.9218 - val_loss: 1.3243 - val_mae: 0.8268 - val_mean_absolute_percentage_error: 112.6227 - val_mse: 0.9419
# Epoch 18/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2904 - mae: 0.8164 - mean_absolute_percentage_error: 145.2679 - mse: 0.9143 - val_loss: 1.2998 - val_mae: 0.8267 - val_mean_absolute_percentage_error: 112.4410 - val_mse: 0.9421
# Epoch 19/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2504 - mae: 0.8066 - mean_absolute_percentage_error: 140.0760 - mse: 0.8991 - val_loss: 1.2753 - val_mae: 0.8249 - val_mean_absolute_percentage_error: 116.6876 - val_mse: 0.9402
# Epoch 20/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2384 - mae: 0.8139 - mean_absolute_percentage_error: 121.2072 - mse: 0.9088 - val_loss: 1.2502 - val_mae: 0.8216 - val_mean_absolute_percentage_error: 118.5493 - val_mse: 0.9355
# Epoch 21/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2116 - mae: 0.8097 - mean_absolute_percentage_error: 125.8283 - mse: 0.9019 - val_loss: 1.2318 - val_mae: 0.8210 - val_mean_absolute_percentage_error: 114.6449 - val_mse: 0.9360
# Epoch 22/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1868 - mae: 0.8040 - mean_absolute_percentage_error: 148.3196 - mse: 0.8959 - val_loss: 1.2106 - val_mae: 0.8188 - val_mean_absolute_percentage_error: 116.7328 - val_mse: 0.9323
# Epoch 23/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1881 - mae: 0.8155 - mean_absolute_percentage_error: 124.0338 - mse: 0.9140 - val_loss: 1.1903 - val_mae: 0.8160 - val_mean_absolute_percentage_error: 117.7893 - val_mse: 0.9283
# Epoch 24/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1508 - mae: 0.8048 - mean_absolute_percentage_error: 122.9634 - mse: 0.8928 - val_loss: 1.1732 - val_mae: 0.8153 - val_mean_absolute_percentage_error: 122.0478 - val_mse: 0.9263
# Epoch 25/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.1502 - mae: 0.8110 - mean_absolute_percentage_error: 136.9536 - mse: 0.9072 - val_loss: 1.1587 - val_mae: 0.8134 - val_mean_absolute_percentage_error: 117.4692 - val_mse: 0.9258
# Epoch 26/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.1307 - mae: 0.8089 - mean_absolute_percentage_error: 128.4247 - mse: 0.9012 - val_loss: 1.1447 - val_mae: 0.8117 - val_mean_absolute_percentage_error: 119.6486 - val_mse: 0.9243
# Epoch 27/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1249 - mae: 0.8156 - mean_absolute_percentage_error: 126.6651 - mse: 0.9078 - val_loss: 1.1322 - val_mae: 0.8108 - val_mean_absolute_percentage_error: 121.3234 - val_mse: 0.9237
# Epoch 28/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1028 - mae: 0.8061 - mean_absolute_percentage_error: 125.4966 - mse: 0.8972 - val_loss: 1.1196 - val_mae: 0.8116 - val_mean_absolute_percentage_error: 120.7685 - val_mse: 0.9221
# Epoch 29/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1054 - mae: 0.8137 - mean_absolute_percentage_error: 139.6846 - mse: 0.9104 - val_loss: 1.1075 - val_mae: 0.8082 - val_mean_absolute_percentage_error: 120.7087 - val_mse: 0.9199
# Epoch 30/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0808 - mae: 0.8070 - mean_absolute_percentage_error: 144.7890 - mse: 0.8957 - val_loss: 1.0959 - val_mae: 0.8083 - val_mean_absolute_percentage_error: 126.5197 - val_mse: 0.9176
# Epoch 31/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0709 - mae: 0.8072 - mean_absolute_percentage_error: 192.8731 - mse: 0.8948 - val_loss: 1.0837 - val_mae: 0.8039 - val_mean_absolute_percentage_error: 119.0193 - val_mse: 0.9138
# Epoch 32/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0651 - mae: 0.8069 - mean_absolute_percentage_error: 143.1047 - mse: 0.8975 - val_loss: 1.0717 - val_mae: 0.8013 - val_mean_absolute_percentage_error: 120.3671 - val_mse: 0.9096
# Epoch 33/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0366 - mae: 0.7949 - mean_absolute_percentage_error: 137.4205 - mse: 0.8764 - val_loss: 1.0641 - val_mae: 0.8004 - val_mean_absolute_percentage_error: 119.1718 - val_mse: 0.9091
# Epoch 34/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0318 - mae: 0.7938 - mean_absolute_percentage_error: 134.7988 - mse: 0.8785 - val_loss: 1.0523 - val_mae: 0.7966 - val_mean_absolute_percentage_error: 122.3678 - val_mse: 0.9038
# Epoch 35/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0277 - mae: 0.7969 - mean_absolute_percentage_error: 134.2394 - mse: 0.8810 - val_loss: 1.0501 - val_mae: 0.7980 - val_mean_absolute_percentage_error: 123.6921 - val_mse: 0.9077
# Epoch 36/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0175 - mae: 0.7943 - mean_absolute_percentage_error: 184.1507 - mse: 0.8768 - val_loss: 1.0396 - val_mae: 0.7940 - val_mean_absolute_percentage_error: 126.0251 - val_mse: 0.9029
# Epoch 37/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0158 - mae: 0.7942 - mean_absolute_percentage_error: 125.4040 - mse: 0.8803 - val_loss: 1.0334 - val_mae: 0.7940 - val_mean_absolute_percentage_error: 125.7808 - val_mse: 0.9017
# Epoch 38/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.9945 - mae: 0.7844 - mean_absolute_percentage_error: 127.2059 - mse: 0.8640 - val_loss: 1.0218 - val_mae: 0.7882 - val_mean_absolute_percentage_error: 123.7869 - val_mse: 0.8946
# Epoch 39/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.9823 - mae: 0.7797 - mean_absolute_percentage_error: 147.9223 - mse: 0.8566 - val_loss: 1.0188 - val_mae: 0.7863 - val_mean_absolute_percentage_error: 124.8470 - val_mse: 0.8964
# Epoch 40/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.9827 - mae: 0.7839 - mean_absolute_percentage_error: 127.9807 - mse: 0.8616 - val_loss: 1.0069 - val_mae: 0.7837 - val_mean_absolute_percentage_error: 123.8310 - val_mse: 0.8889
# Epoch 41/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.9815 - mae: 0.7821 - mean_absolute_percentage_error: 142.4769 - mse: 0.8645 - val_loss: 1.0042 - val_mae: 0.7866 - val_mean_absolute_percentage_error: 131.9403 - val_mse: 0.8900
# Epoch 42/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.9745 - mae: 0.7809 - mean_absolute_percentage_error: 117.7553 - mse: 0.8614 - val_loss: 1.0018 - val_mae: 0.7834 - val_mean_absolute_percentage_error: 114.5336 - val_mse: 0.8916
# Epoch 43/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9622 - mae: 0.7761 - mean_absolute_percentage_error: 130.9769 - mse: 0.8531 - val_loss: 0.9927 - val_mae: 0.7807 - val_mean_absolute_percentage_error: 127.1342 - val_mse: 0.8861
# Epoch 44/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9585 - mae: 0.7758 - mean_absolute_percentage_error: 137.5064 - mse: 0.8526 - val_loss: 0.9900 - val_mae: 0.7795 - val_mean_absolute_percentage_error: 118.2253 - val_mse: 0.8866
# Epoch 45/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9664 - mae: 0.7826 - mean_absolute_percentage_error: 131.0098 - mse: 0.8638 - val_loss: 0.9820 - val_mae: 0.7774 - val_mean_absolute_percentage_error: 125.5961 - val_mse: 0.8814
# Epoch 46/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9581 - mae: 0.7784 - mean_absolute_percentage_error: 136.7548 - mse: 0.8582 - val_loss: 0.9800 - val_mae: 0.7796 - val_mean_absolute_percentage_error: 128.5501 - val_mse: 0.8823
# Epoch 47/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9491 - mae: 0.7760 - mean_absolute_percentage_error: 147.3296 - mse: 0.8519 - val_loss: 0.9814 - val_mae: 0.7829 - val_mean_absolute_percentage_error: 125.4700 - val_mse: 0.8865
# Epoch 48/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9502 - mae: 0.7763 - mean_absolute_percentage_error: 126.5884 - mse: 0.8558 - val_loss: 0.9715 - val_mae: 0.7763 - val_mean_absolute_percentage_error: 126.0475 - val_mse: 0.8786
# Epoch 49/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9460 - mae: 0.7741 - mean_absolute_percentage_error: 128.4921 - mse: 0.8537 - val_loss: 0.9706 - val_mae: 0.7802 - val_mean_absolute_percentage_error: 128.6211 - val_mse: 0.8799
# Epoch 50/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9245 - mae: 0.7666 - mean_absolute_percentage_error: 127.7832 - mse: 0.8343 - val_loss: 0.9653 - val_mae: 0.7743 - val_mean_absolute_percentage_error: 123.5934 - val_mse: 0.8765
# Epoch 51/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9262 - mae: 0.7659 - mean_absolute_percentage_error: 134.3583 - mse: 0.8379 - val_loss: 0.9641 - val_mae: 0.7770 - val_mean_absolute_percentage_error: 127.3304 - val_mse: 0.8772
# Epoch 52/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9327 - mae: 0.7718 - mean_absolute_percentage_error: 129.8859 - mse: 0.8461 - val_loss: 0.9608 - val_mae: 0.7725 - val_mean_absolute_percentage_error: 127.3605 - val_mse: 0.8753
# Epoch 53/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9145 - mae: 0.7616 - mean_absolute_percentage_error: 144.1048 - mse: 0.8294 - val_loss: 0.9661 - val_mae: 0.7789 - val_mean_absolute_percentage_error: 127.2785 - val_mse: 0.8825
# Epoch 54/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9326 - mae: 0.7727 - mean_absolute_percentage_error: 158.4057 - mse: 0.8494 - val_loss: 0.9530 - val_mae: 0.7718 - val_mean_absolute_percentage_error: 130.9512 - val_mse: 0.8707
# Epoch 55/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9235 - mae: 0.7679 - mean_absolute_percentage_error: 138.0555 - mse: 0.8414 - val_loss: 0.9521 - val_mae: 0.7699 - val_mean_absolute_percentage_error: 126.1286 - val_mse: 0.8711
# Epoch 56/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9148 - mae: 0.7647 - mean_absolute_percentage_error: 147.7444 - mse: 0.8342 - val_loss: 0.9507 - val_mae: 0.7664 - val_mean_absolute_percentage_error: 131.9109 - val_mse: 0.8707
# Epoch 57/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9241 - mae: 0.7672 - mean_absolute_percentage_error: 124.3463 - mse: 0.8444 - val_loss: 0.9485 - val_mae: 0.7672 - val_mean_absolute_percentage_error: 121.3858 - val_mse: 0.8697
# Epoch 58/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9030 - mae: 0.7584 - mean_absolute_percentage_error: 124.0257 - mse: 0.8245 - val_loss: 0.9459 - val_mae: 0.7678 - val_mean_absolute_percentage_error: 130.6677 - val_mse: 0.8682
# Epoch 59/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9021 - mae: 0.7583 - mean_absolute_percentage_error: 137.4088 - mse: 0.8247 - val_loss: 0.9431 - val_mae: 0.7674 - val_mean_absolute_percentage_error: 127.9297 - val_mse: 0.8666
# Epoch 60/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9015 - mae: 0.7570 - mean_absolute_percentage_error: 146.5035 - mse: 0.8252 - val_loss: 0.9418 - val_mae: 0.7676 - val_mean_absolute_percentage_error: 124.4718 - val_mse: 0.8662
# Epoch 61/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9046 - mae: 0.7592 - mean_absolute_percentage_error: 128.4267 - mse: 0.8292 - val_loss: 0.9423 - val_mae: 0.7658 - val_mean_absolute_percentage_error: 122.8456 - val_mse: 0.8677
# Epoch 62/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9042 - mae: 0.7614 - mean_absolute_percentage_error: 123.5525 - mse: 0.8297 - val_loss: 0.9376 - val_mae: 0.7641 - val_mean_absolute_percentage_error: 126.9802 - val_mse: 0.8638
# Epoch 63/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8969 - mae: 0.7568 - mean_absolute_percentage_error: 135.7089 - mse: 0.8234 - val_loss: 0.9414 - val_mae: 0.7657 - val_mean_absolute_percentage_error: 123.9055 - val_mse: 0.8684
# Epoch 64/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8946 - mae: 0.7547 - mean_absolute_percentage_error: 131.4955 - mse: 0.8218 - val_loss: 0.9371 - val_mae: 0.7661 - val_mean_absolute_percentage_error: 132.3686 - val_mse: 0.8649
# Epoch 65/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8967 - mae: 0.7565 - mean_absolute_percentage_error: 121.4979 - mse: 0.8246 - val_loss: 0.9349 - val_mae: 0.7620 - val_mean_absolute_percentage_error: 128.4015 - val_mse: 0.8633
# Epoch 66/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8941 - mae: 0.7557 - mean_absolute_percentage_error: 135.7028 - mse: 0.8227 - val_loss: 0.9340 - val_mae: 0.7632 - val_mean_absolute_percentage_error: 118.8323 - val_mse: 0.8631
# Epoch 67/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9080 - mae: 0.7637 - mean_absolute_percentage_error: 134.7271 - mse: 0.8372 - val_loss: 0.9360 - val_mae: 0.7640 - val_mean_absolute_percentage_error: 129.3931 - val_mse: 0.8657
# Epoch 68/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8908 - mae: 0.7532 - mean_absolute_percentage_error: 132.7707 - mse: 0.8205 - val_loss: 0.9315 - val_mae: 0.7630 - val_mean_absolute_percentage_error: 122.4768 - val_mse: 0.8617
# Epoch 69/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8937 - mae: 0.7558 - mean_absolute_percentage_error: 128.5571 - mse: 0.8240 - val_loss: 0.9304 - val_mae: 0.7583 - val_mean_absolute_percentage_error: 123.6237 - val_mse: 0.8611
# Epoch 70/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9001 - mae: 0.7603 - mean_absolute_percentage_error: 126.2033 - mse: 0.8310 - val_loss: 0.9310 - val_mae: 0.7610 - val_mean_absolute_percentage_error: 124.2680 - val_mse: 0.8625
# Epoch 71/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8916 - mae: 0.7568 - mean_absolute_percentage_error: 137.3437 - mse: 0.8232 - val_loss: 0.9296 - val_mae: 0.7677 - val_mean_absolute_percentage_error: 136.8367 - val_mse: 0.8616
# Epoch 72/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8899 - mae: 0.7553 - mean_absolute_percentage_error: 119.7072 - mse: 0.8220 - val_loss: 0.9313 - val_mae: 0.7635 - val_mean_absolute_percentage_error: 125.3780 - val_mse: 0.8637
# Epoch 73/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8870 - mae: 0.7535 - mean_absolute_percentage_error: 131.7719 - mse: 0.8195 - val_loss: 0.9283 - val_mae: 0.7585 - val_mean_absolute_percentage_error: 128.8706 - val_mse: 0.8612
# Epoch 74/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8938 - mae: 0.7585 - mean_absolute_percentage_error: 150.5123 - mse: 0.8269 - val_loss: 0.9291 - val_mae: 0.7618 - val_mean_absolute_percentage_error: 129.9626 - val_mse: 0.8625
# Epoch 75/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8807 - mae: 0.7503 - mean_absolute_percentage_error: 126.7117 - mse: 0.8142 - val_loss: 0.9293 - val_mae: 0.7643 - val_mean_absolute_percentage_error: 125.9700 - val_mse: 0.8633
# Epoch 76/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8788 - mae: 0.7493 - mean_absolute_percentage_error: 143.6711 - mse: 0.8128 - val_loss: 0.9273 - val_mae: 0.7601 - val_mean_absolute_percentage_error: 127.5921 - val_mse: 0.8616
# Epoch 77/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8900 - mae: 0.7570 - mean_absolute_percentage_error: 140.8036 - mse: 0.8244 - val_loss: 0.9299 - val_mae: 0.7599 - val_mean_absolute_percentage_error: 115.6512 - val_mse: 0.8645
# Epoch 78/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8853 - mae: 0.7517 - mean_absolute_percentage_error: 147.5447 - mse: 0.8201 - val_loss: 0.9249 - val_mae: 0.7596 - val_mean_absolute_percentage_error: 132.2293 - val_mse: 0.8599
# Epoch 79/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8734 - mae: 0.7467 - mean_absolute_percentage_error: 127.8379 - mse: 0.8086 - val_loss: 0.9278 - val_mae: 0.7596 - val_mean_absolute_percentage_error: 117.1523 - val_mse: 0.8633
# Epoch 80/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8801 - mae: 0.7512 - mean_absolute_percentage_error: 150.3430 - mse: 0.8156 - val_loss: 0.9248 - val_mae: 0.7628 - val_mean_absolute_percentage_error: 128.6796 - val_mse: 0.8602
# Epoch 81/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8779 - mae: 0.7513 - mean_absolute_percentage_error: 140.9863 - mse: 0.8136 - val_loss: 0.9248 - val_mae: 0.7588 - val_mean_absolute_percentage_error: 128.9378 - val_mse: 0.8608
# Epoch 82/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8824 - mae: 0.7523 - mean_absolute_percentage_error: 119.4286 - mse: 0.8186 - val_loss: 0.9274 - val_mae: 0.7606 - val_mean_absolute_percentage_error: 116.9576 - val_mse: 0.8638
# Epoch 83/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8737 - mae: 0.7466 - mean_absolute_percentage_error: 128.0140 - mse: 0.8102 - val_loss: 0.9213 - val_mae: 0.7588 - val_mean_absolute_percentage_error: 123.0984 - val_mse: 0.8582
# Epoch 84/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8717 - mae: 0.7460 - mean_absolute_percentage_error: 150.0665 - mse: 0.8087 - val_loss: 0.9230 - val_mae: 0.7619 - val_mean_absolute_percentage_error: 132.9502 - val_mse: 0.8602
# Epoch 85/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8641 - mae: 0.7412 - mean_absolute_percentage_error: 128.3154 - mse: 0.8013 - val_loss: 0.9189 - val_mae: 0.7548 - val_mean_absolute_percentage_error: 127.0678 - val_mse: 0.8562
# Epoch 86/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8574 - mae: 0.7373 - mean_absolute_percentage_error: 141.9809 - mse: 0.7948 - val_loss: 0.9254 - val_mae: 0.7590 - val_mean_absolute_percentage_error: 127.6945 - val_mse: 0.8628
# Epoch 87/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8676 - mae: 0.7459 - mean_absolute_percentage_error: 123.9070 - mse: 0.8050 - val_loss: 0.9256 - val_mae: 0.7608 - val_mean_absolute_percentage_error: 119.9070 - val_mse: 0.8631
# Epoch 88/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8602 - mae: 0.7381 - mean_absolute_percentage_error: 155.6523 - mse: 0.7977 - val_loss: 0.9194 - val_mae: 0.7559 - val_mean_absolute_percentage_error: 124.3986 - val_mse: 0.8570
# Epoch 89/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8658 - mae: 0.7415 - mean_absolute_percentage_error: 129.9113 - mse: 0.8034 - val_loss: 0.9215 - val_mae: 0.7598 - val_mean_absolute_percentage_error: 129.3720 - val_mse: 0.8593
# Epoch 90/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8693 - mae: 0.7428 - mean_absolute_percentage_error: 139.4366 - mse: 0.8072 - val_loss: 0.9205 - val_mae: 0.7550 - val_mean_absolute_percentage_error: 123.1298 - val_mse: 0.8584
# Epoch 91/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8691 - mae: 0.7436 - mean_absolute_percentage_error: 140.2983 - mse: 0.8070 - val_loss: 0.9203 - val_mae: 0.7545 - val_mean_absolute_percentage_error: 131.6281 - val_mse: 0.8584
# Epoch 92/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8646 - mae: 0.7427 - mean_absolute_percentage_error: 130.1135 - mse: 0.8027 - val_loss: 0.9225 - val_mae: 0.7594 - val_mean_absolute_percentage_error: 119.9710 - val_mse: 0.8609
# Epoch 93/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8640 - mae: 0.7422 - mean_absolute_percentage_error: 137.8108 - mse: 0.8023 - val_loss: 0.9200 - val_mae: 0.7594 - val_mean_absolute_percentage_error: 136.5410 - val_mse: 0.8584
# Epoch 94/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8568 - mae: 0.7362 - mean_absolute_percentage_error: 140.3001 - mse: 0.7951 - val_loss: 0.9199 - val_mae: 0.7570 - val_mean_absolute_percentage_error: 126.7213 - val_mse: 0.8582
# Epoch 95/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8541 - mae: 0.7362 - mean_absolute_percentage_error: 134.6144 - mse: 0.7923 - val_loss: 0.9192 - val_mae: 0.7593 - val_mean_absolute_percentage_error: 134.4402 - val_mse: 0.8576
# Epoch 96/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8631 - mae: 0.7400 - mean_absolute_percentage_error: 141.3002 - mse: 0.8016 - val_loss: 0.9188 - val_mae: 0.7560 - val_mean_absolute_percentage_error: 122.8477 - val_mse: 0.8574
# Epoch 97/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8726 - mae: 0.7454 - mean_absolute_percentage_error: 122.4071 - mse: 0.8112 - val_loss: 0.9171 - val_mae: 0.7532 - val_mean_absolute_percentage_error: 122.3707 - val_mse: 0.8558
# Epoch 98/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.8603 - mae: 0.7389 - mean_absolute_percentage_error: 124.9249 - mse: 0.7990 - val_loss: 0.9192 - val_mae: 0.7556 - val_mean_absolute_percentage_error: 127.2131 - val_mse: 0.8579
# Epoch 99/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8438 - mae: 0.7287 - mean_absolute_percentage_error: 141.7246 - mse: 0.7825 - val_loss: 0.9186 - val_mae: 0.7542 - val_mean_absolute_percentage_error: 130.5978 - val_mse: 0.8573
# Epoch 100/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8488 - mae: 0.7333 - mean_absolute_percentage_error: 147.6367 - mse: 0.7874 - val_loss: 0.9182 - val_mae: 0.7570 - val_mean_absolute_percentage_error: 120.9490 - val_mse: 0.8569
# Epoch 101/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8641 - mae: 0.7441 - mean_absolute_percentage_error: 155.8194 - mse: 0.8026 - val_loss: 0.9205 - val_mae: 0.7544 - val_mean_absolute_percentage_error: 123.8718 - val_mse: 0.8590
# Epoch 102/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8430 - mae: 0.7285 - mean_absolute_percentage_error: 137.8176 - mse: 0.7816 - val_loss: 0.9221 - val_mae: 0.7562 - val_mean_absolute_percentage_error: 122.4596 - val_mse: 0.8607
# Epoch 103/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8535 - mae: 0.7346 - mean_absolute_percentage_error: 131.4835 - mse: 0.7921 - val_loss: 0.9175 - val_mae: 0.7543 - val_mean_absolute_percentage_error: 136.9671 - val_mse: 0.8561
# Epoch 104/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8480 - mae: 0.7330 - mean_absolute_percentage_error: 137.5178 - mse: 0.7865 - val_loss: 0.9155 - val_mae: 0.7540 - val_mean_absolute_percentage_error: 123.2004 - val_mse: 0.8539
# Epoch 105/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8533 - mae: 0.7360 - mean_absolute_percentage_error: 131.1930 - mse: 0.7917 - val_loss: 0.9190 - val_mae: 0.7530 - val_mean_absolute_percentage_error: 119.9733 - val_mse: 0.8573
# Epoch 106/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8482 - mae: 0.7297 - mean_absolute_percentage_error: 125.1177 - mse: 0.7865 - val_loss: 0.9194 - val_mae: 0.7518 - val_mean_absolute_percentage_error: 130.2682 - val_mse: 0.8576
# Epoch 107/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8519 - mae: 0.7336 - mean_absolute_percentage_error: 129.8567 - mse: 0.7901 - val_loss: 0.9194 - val_mae: 0.7532 - val_mean_absolute_percentage_error: 126.7640 - val_mse: 0.8575
# Epoch 108/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8305 - mae: 0.7227 - mean_absolute_percentage_error: 176.9293 - mse: 0.7684 - val_loss: 0.9219 - val_mae: 0.7571 - val_mean_absolute_percentage_error: 127.3141 - val_mse: 0.8599
# Epoch 109/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8499 - mae: 0.7332 - mean_absolute_percentage_error: 158.4007 - mse: 0.7880 - val_loss: 0.9200 - val_mae: 0.7564 - val_mean_absolute_percentage_error: 136.7371 - val_mse: 0.8582
# Epoch 110/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8402 - mae: 0.7297 - mean_absolute_percentage_error: 138.7971 - mse: 0.7783 - val_loss: 0.9206 - val_mae: 0.7536 - val_mean_absolute_percentage_error: 126.1109 - val_mse: 0.8585
# Epoch 111/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.8397 - mae: 0.7269 - mean_absolute_percentage_error: 120.0732 - mse: 0.7777 - val_loss: 0.9252 - val_mae: 0.7556 - val_mean_absolute_percentage_error: 131.5895 - val_mse: 0.8630
# Epoch 112/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8440 - mae: 0.7292 - mean_absolute_percentage_error: 142.9696 - mse: 0.7818 - val_loss: 0.9226 - val_mae: 0.7556 - val_mean_absolute_percentage_error: 129.8008 - val_mse: 0.8603
# Epoch 113/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8438 - mae: 0.7274 - mean_absolute_percentage_error: 138.9433 - mse: 0.7813 - val_loss: 0.9240 - val_mae: 0.7561 - val_mean_absolute_percentage_error: 125.9359 - val_mse: 0.8615
# Epoch 114/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8494 - mae: 0.7314 - mean_absolute_percentage_error: 128.3140 - mse: 0.7868 - val_loss: 0.9218 - val_mae: 0.7578 - val_mean_absolute_percentage_error: 129.8114 - val_mse: 0.8592
# Epoch 115/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8394 - mae: 0.7277 - mean_absolute_percentage_error: 129.7451 - mse: 0.7767 - val_loss: 0.9249 - val_mae: 0.7564 - val_mean_absolute_percentage_error: 126.7973 - val_mse: 0.8621
# Epoch 116/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8406 - mae: 0.7275 - mean_absolute_percentage_error: 126.5426 - mse: 0.7778 - val_loss: 0.9260 - val_mae: 0.7567 - val_mean_absolute_percentage_error: 129.1077 - val_mse: 0.8632
# Epoch 117/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8380 - mae: 0.7278 - mean_absolute_percentage_error: 138.7923 - mse: 0.7751 - val_loss: 0.9217 - val_mae: 0.7530 - val_mean_absolute_percentage_error: 135.0427 - val_mse: 0.8586
# Epoch 118/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8389 - mae: 0.7260 - mean_absolute_percentage_error: 140.0284 - mse: 0.7758 - val_loss: 0.9282 - val_mae: 0.7587 - val_mean_absolute_percentage_error: 135.7265 - val_mse: 0.8649
# Epoch 119/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8447 - mae: 0.7297 - mean_absolute_percentage_error: 150.6755 - mse: 0.7814 - val_loss: 0.9219 - val_mae: 0.7533 - val_mean_absolute_percentage_error: 127.6350 - val_mse: 0.8586
# Epoch 120/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8354 - mae: 0.7238 - mean_absolute_percentage_error: 131.2928 - mse: 0.7720 - val_loss: 0.9224 - val_mae: 0.7557 - val_mean_absolute_percentage_error: 139.0682 - val_mse: 0.8590
# Epoch 121/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8333 - mae: 0.7238 - mean_absolute_percentage_error: 173.3131 - mse: 0.7698 - val_loss: 0.9246 - val_mae: 0.7543 - val_mean_absolute_percentage_error: 133.0482 - val_mse: 0.8609
# Epoch 122/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8283 - mae: 0.7175 - mean_absolute_percentage_error: 133.9636 - mse: 0.7645 - val_loss: 0.9243 - val_mae: 0.7535 - val_mean_absolute_percentage_error: 135.7655 - val_mse: 0.8605
# Epoch 123/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8296 - mae: 0.7188 - mean_absolute_percentage_error: 131.1415 - mse: 0.7657 - val_loss: 0.9237 - val_mae: 0.7535 - val_mean_absolute_percentage_error: 136.0907 - val_mse: 0.8596
# Epoch 124/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8357 - mae: 0.7242 - mean_absolute_percentage_error: 135.4897 - mse: 0.7714 - val_loss: 0.9207 - val_mae: 0.7557 - val_mean_absolute_percentage_error: 131.4288 - val_mse: 0.8564
# Epoch 125/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8372 - mae: 0.7251 - mean_absolute_percentage_error: 132.7695 - mse: 0.7728 - val_loss: 0.9248 - val_mae: 0.7535 - val_mean_absolute_percentage_error: 129.4990 - val_mse: 0.8603
# Epoch 126/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8405 - mae: 0.7287 - mean_absolute_percentage_error: 129.5482 - mse: 0.7758 - val_loss: 0.9340 - val_mae: 0.7581 - val_mean_absolute_percentage_error: 141.9585 - val_mse: 0.8691
# Epoch 127/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8279 - mae: 0.7188 - mean_absolute_percentage_error: 130.7628 - mse: 0.7630 - val_loss: 0.9250 - val_mae: 0.7532 - val_mean_absolute_percentage_error: 128.6740 - val_mse: 0.8601
# Epoch 128/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8310 - mae: 0.7221 - mean_absolute_percentage_error: 144.5544 - mse: 0.7660 - val_loss: 0.9294 - val_mae: 0.7552 - val_mean_absolute_percentage_error: 140.5230 - val_mse: 0.8643
# Epoch 129/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8284 - mae: 0.7193 - mean_absolute_percentage_error: 131.6323 - mse: 0.7633 - val_loss: 0.9275 - val_mae: 0.7536 - val_mean_absolute_percentage_error: 140.1845 - val_mse: 0.8622
# Epoch 130/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8364 - mae: 0.7250 - mean_absolute_percentage_error: 127.2098 - mse: 0.7712 - val_loss: 0.9266 - val_mae: 0.7521 - val_mean_absolute_percentage_error: 136.0356 - val_mse: 0.8611
# Epoch 131/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8253 - mae: 0.7189 - mean_absolute_percentage_error: 146.4771 - mse: 0.7600 - val_loss: 0.9256 - val_mae: 0.7541 - val_mean_absolute_percentage_error: 134.9930 - val_mse: 0.8601
# Epoch 132/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8167 - mae: 0.7118 - mean_absolute_percentage_error: 132.5670 - mse: 0.7511 - val_loss: 0.9318 - val_mae: 0.7592 - val_mean_absolute_percentage_error: 136.2836 - val_mse: 0.8660
# Epoch 133/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8278 - mae: 0.7178 - mean_absolute_percentage_error: 157.7648 - mse: 0.7618 - val_loss: 0.9271 - val_mae: 0.7573 - val_mean_absolute_percentage_error: 136.8104 - val_mse: 0.8611
# Epoch 134/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8234 - mae: 0.7163 - mean_absolute_percentage_error: 135.4122 - mse: 0.7573 - val_loss: 0.9303 - val_mae: 0.7587 - val_mean_absolute_percentage_error: 136.0433 - val_mse: 0.8642
# Epoch 135/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8291 - mae: 0.7187 - mean_absolute_percentage_error: 143.0112 - mse: 0.7629 - val_loss: 0.9308 - val_mae: 0.7544 - val_mean_absolute_percentage_error: 135.4176 - val_mse: 0.8645
# Epoch 136/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.8210 - mae: 0.7135 - mean_absolute_percentage_error: 133.0297 - mse: 0.7547 - val_loss: 0.9273 - val_mae: 0.7540 - val_mean_absolute_percentage_error: 146.4660 - val_mse: 0.8609
# Epoch 137/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8164 - mae: 0.7114 - mean_absolute_percentage_error: 171.5237 - mse: 0.7498 - val_loss: 0.9354 - val_mae: 0.7568 - val_mean_absolute_percentage_error: 134.0985 - val_mse: 0.8686
# Epoch 138/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8318 - mae: 0.7180 - mean_absolute_percentage_error: 130.5356 - mse: 0.7650 - val_loss: 0.9347 - val_mae: 0.7559 - val_mean_absolute_percentage_error: 140.5627 - val_mse: 0.8677
# Epoch 139/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8234 - mae: 0.7151 - mean_absolute_percentage_error: 145.1887 - mse: 0.7563 - val_loss: 0.9328 - val_mae: 0.7515 - val_mean_absolute_percentage_error: 142.2205 - val_mse: 0.8656
# Epoch 140/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8126 - mae: 0.7066 - mean_absolute_percentage_error: 134.5936 - mse: 0.7453 - val_loss: 0.9324 - val_mae: 0.7547 - val_mean_absolute_percentage_error: 134.8219 - val_mse: 0.8650
# Epoch 141/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8293 - mae: 0.7155 - mean_absolute_percentage_error: 133.8202 - mse: 0.7618 - val_loss: 0.9267 - val_mae: 0.7525 - val_mean_absolute_percentage_error: 139.4198 - val_mse: 0.8591
# Epoch 142/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8130 - mae: 0.7088 - mean_absolute_percentage_error: 137.6265 - mse: 0.7453 - val_loss: 0.9381 - val_mae: 0.7573 - val_mean_absolute_percentage_error: 146.6070 - val_mse: 0.8702
# Epoch 143/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8176 - mae: 0.7103 - mean_absolute_percentage_error: 135.5332 - mse: 0.7497 - val_loss: 0.9350 - val_mae: 0.7578 - val_mean_absolute_percentage_error: 142.9313 - val_mse: 0.8669
# Epoch 144/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8088 - mae: 0.7065 - mean_absolute_percentage_error: 141.8097 - mse: 0.7407 - val_loss: 0.9322 - val_mae: 0.7545 - val_mean_absolute_percentage_error: 142.0721 - val_mse: 0.8639
# Epoch 145/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8110 - mae: 0.7036 - mean_absolute_percentage_error: 139.9292 - mse: 0.7426 - val_loss: 0.9366 - val_mae: 0.7540 - val_mean_absolute_percentage_error: 140.6701 - val_mse: 0.8682
# Epoch 146/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8144 - mae: 0.7070 - mean_absolute_percentage_error: 151.5714 - mse: 0.7459 - val_loss: 0.9322 - val_mae: 0.7532 - val_mean_absolute_percentage_error: 145.1010 - val_mse: 0.8635
# Epoch 147/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8202 - mae: 0.7086 - mean_absolute_percentage_error: 137.4452 - mse: 0.7514 - val_loss: 0.9408 - val_mae: 0.7599 - val_mean_absolute_percentage_error: 148.2443 - val_mse: 0.8718
# Epoch 148/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8109 - mae: 0.7072 - mean_absolute_percentage_error: 147.1662 - mse: 0.7419 - val_loss: 0.9391 - val_mae: 0.7567 - val_mean_absolute_percentage_error: 143.9588 - val_mse: 0.8699
# Epoch 149/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8121 - mae: 0.7055 - mean_absolute_percentage_error: 158.8574 - mse: 0.7428 - val_loss: 0.9486 - val_mae: 0.7582 - val_mean_absolute_percentage_error: 147.6139 - val_mse: 0.8791
# Epoch 150/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8074 - mae: 0.7030 - mean_absolute_percentage_error: 135.9129 - mse: 0.7377 - val_loss: 0.9344 - val_mae: 0.7504 - val_mean_absolute_percentage_error: 142.6034 - val_mse: 0.8645

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae  mean_absolute_percentage_error       mse  val_loss  \
# 145  0.809708  0.704878                      150.944687  0.741162  0.932227
# 146  0.814616  0.707906                      140.834641  0.745812  0.940764
# 147  0.812091  0.707534                      150.189056  0.743035  0.939147
# 148  0.811261  0.705922                      155.080383  0.741839  0.948629
# 149  0.803885  0.701748                      139.180222  0.734162  0.934421
#
#       val_mae  val_mean_absolute_percentage_error   val_mse  epoch
# 145  0.753184                          145.101013  0.863479    145
# 146  0.759862                          148.244278  0.871841    146
# 147  0.756660                          143.958817  0.869890    147
# 148  0.758180                          147.613907  0.879051    148
# 149  0.750413                          142.603439  0.864524    149

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

plt.figure()
plt.title("Evolução das funções de perda durante o treinamento da rede")
plt.xlabel('Rodada')
plt.ylabel('Mean Square Error')
plt.plot(hist['epoch'], hist['mse'], label='MSE Treino')
plt.plot(hist['epoch'], hist['val_mse'], label = 'MSE Validação')
plt.legend()

plt.figure()
plt.xlabel('Rodada')
plt.ylabel('Mean Absolute Error')
plt.plot(hist['epoch'], hist['mae'], label='MAE Treino')
plt.plot(hist['epoch'], hist['val_mae'], label = 'MAE Validação')
plt.legend()

plt.show()

# %% [markdown]
# ## Prevendo a amostra de teste

# %% [markdown]
# ### Ajustando a base de teste

# %%
x_t = pd.DataFrame(test[0])
x_t.head()
# Out:
#                                                     0
# 9   [0.0, 0.000274658203125, 0.0010986328125, 0.00...
# 11  [0.0, -3.0517578125e-05, 3.0517578125e-05, -9....
# 19  [0.0, -3.0517578125e-05, -3.0517578125e-05, 0....
# 23  [0.0, 0.0, -0.00030517578125, 0.00067138671875...
# 24  [0.0, 0.0009765625, 0.00067138671875, -0.00238...

# %%
x_t = np.array(x_t[0].values.tolist())
x_t[0]
# Out:
# array([0.00000000e+00, 2.74658203e-04, 1.09863281e-03, ...,
#        3.05175781e-05, 3.05175781e-05, 0.00000000e+00])

# %%
len(x_t[0])
# Out:
# 22050

# %%
y_t = test.drop(columns=[0])
y_t.head()
# Out:
#     frequencia_base  amplitude1  frequency1  beta2  amplitude2  frequency2  \
# 9           754.300       0.439       0.130  0.227       0.888       0.341
# 11        11311.801       0.522       0.972  0.153       0.246       0.151
# 19        18037.688       0.487       0.331  0.963       0.840       0.712
# 23         9422.470       0.191       0.071  0.175       0.096       0.089
# 24         4144.917       0.688       0.532  0.586       0.917       0.355
#
#     beta3  amplitude3  frequency3  beta4  ...  frequency4  beta5  amplitude5  \
# 9   0.712       0.756       0.583  0.495  ...       0.197  0.053       0.912
# 11  0.578       0.137       0.151  0.719  ...       0.345  0.559       0.289
# 19  0.086       0.267       0.298  0.299  ...       0.636  0.726       0.170
# 23  0.359       0.383       0.495  0.844  ...       0.526  0.534       0.844
# 24  0.962       0.175       0.897  0.163  ...       0.305  0.673       0.501
#
#     frequency5  beta_carrier  amplitude_carrier  attack  decay  sustain  \
# 9        0.663         0.174              0.721   0.027  0.038    0.083
# 11       0.228         0.414              0.243   0.159  0.077    0.446
# 19       0.599         0.487              0.082   0.188  0.043    0.441
# 23       0.454         0.486              0.413   0.081  0.100    0.284
# 24       0.414         0.974              0.514   0.023  0.091    0.470
#
#     release
# 9     0.152
# 11    0.084
# 19    0.049
# 23    0.150
# 24    0.157
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Chamando o modelo para predição

# %%
y_pred_norm = model.predict(x_t)
# Out:
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d21905d42c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step

# %%
y_pred = scaler_y.inverse_transform(y_pred_norm)

# %%
y_pred = pd.DataFrame(y_pred)
y_pred.head()
# Out:
#              0         1         2         3         4         5         6   \
# 0   4931.918457  0.575477  0.569029  0.503985  0.567518  0.588041  0.466130
# 1  12083.111328  0.499726  0.417380  0.486309  0.475982  0.478641  0.524589
# 2   9731.246094  0.517689  0.478936  0.565820  0.539864  0.486695  0.524020
# 3  13383.025391  0.565424  0.452481  0.481542  0.449805  0.521103  0.549206
# 4   9421.501953  0.562351  0.563392  0.585591  0.496214  0.518776  0.460228
#
#          7         8         9   ...        11        12        13        14  \
# 0  0.529144  0.484308  0.496206  ...  0.478627  0.521264  0.497267  0.541472
# 1  0.481969  0.537442  0.511910  ...  0.470831  0.501768  0.497481  0.513382
# 2  0.477359  0.572339  0.485873  ...  0.508672  0.490366  0.454006  0.548684
# 3  0.548248  0.577037  0.387869  ...  0.508255  0.520776  0.547935  0.515140
# 4  0.562392  0.660297  0.451602  ...  0.448264  0.605996  0.432919  0.673172
#
#          15        16        17        18        19        20
# 0  0.476004  0.582298  0.028765  0.050169  0.089400  0.095039
# 1  0.488100  0.260858  0.143712  0.059006  0.387228  0.105905
# 2  0.457375  0.086804  0.144198  0.048158  0.365548  0.093121
# 3  0.475109  0.434720  0.083201  0.081716  0.275834  0.109989
# 4  0.427472  0.550232  0.053712  0.063763  0.439679  0.108592
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Calculando erro de teste

# %%
mse = tf.keras.losses.MSE(y_t, y_pred).numpy().mean()
mae = tf.keras.losses.MAE(y_t, y_pred).numpy().mean()
rmse = np.sqrt(mse)

# %%
print(f"RMSE Test: {rmse}")
print(f"MSE Test: {mse}")
print(f"MAE Test: {mae}")
# Out:
# RMSE Test: 1184.77197265625
# MSE Test: 1403684.625
# MAE Test: 214.58750915527344
