# %% [markdown]
# # Testando um modelo simples de aprendizado de um Datase aleatório

# %% [markdown]
# ## Imports

# %%
import IPython.display as ipd
import json
import numpy as np
import matplotlib.pyplot as plt
import random
import soundfile as sf
import pandas as pd

from fm_synth import FMSynth, SAMPLE_RATE

# %% [markdown]
# ## Gerando um dataset aleatório

# %% [markdown]
# ### Rodando aleatoriamente e salvando o resultado

# %%
duracao_amostras = 4
tamanho_dataset = 1000
precisao_decimal = 3

# %%
# with open("dataset/parameters.json", "w") as f:
#     f.write("[\n")
#     for i in range(tamanho_dataset):
#         # Sorteando uma frequencia báse, na faixa audível humana
#         frequencia_base = random.random() * 20000 + 20
#         frequencia_base = round(frequencia_base, precisao_decimal)

#         # Sorteando os demais parâmetros da síntese
#         amplitude1 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         frequency1 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         beta2 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         amplitude2 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         frequency2 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         beta3 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         amplitude3 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         frequency3 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         beta4 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         amplitude4 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         frequency4 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         beta5 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         amplitude5 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         frequency5 = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         beta_carrier = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         amplitude_carrier = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         attack = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         decay = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         sustain = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         release = round((random.random() * 0.999 + 0.001), precisao_decimal)
#         if decay <= 0:
#             print(decay)

#         # Guardando os parâmetros em JSON
#         data = {
#             "id": i,
#             "frequencia_base": frequencia_base,
#             "amplitude1": amplitude1,
#             "frequency1": frequency1,
#             "beta2": beta2,
#             "amplitude2": amplitude2,
#             "frequency2": frequency2,
#             "beta3": beta3,
#             "amplitude3": amplitude3,
#             "frequency3": frequency3,
#             "beta4": beta4,
#             "amplitude4": amplitude4,
#             "frequency4": frequency4,
#             "beta5": beta5,
#             "amplitude5": amplitude5,
#             "frequency5": frequency5,
#             "beta_carrier": beta_carrier,
#             "amplitude_carrier": amplitude_carrier,
#             "attack": attack,
#             "decay": decay,
#             "sustain": sustain,
#             "release": release,
#         }

#         # Codificando os parâmetros em json
#         data = json.dumps(data)

#         # Imprimindo na saída
#         f.write(data)
#         if (i<tamanho_dataset-1):
#             f.write(",\n")
#         else:
#             f.write("\n")

#         # Sintetizando o sinal
#         fm_synth = FMSynth(
#             amplitude1=amplitude1,
#             frequency1=frequency1,
#             beta2=beta2,
#             amplitude2=amplitude2,
#             frequency2=frequency2,
#             beta3=beta3,
#             amplitude3=amplitude3,
#             frequency3=frequency3,
#             beta4=beta4,
#             amplitude4=amplitude4,
#             frequency4=frequency4,
#             beta5=beta5,
#             amplitude5=amplitude5,
#             frequency5=frequency5,
#             beta_carrier=beta_carrier,
#             amplitude_carrier=amplitude_carrier,
#             attack=attack,
#             decay=decay,
#             sustain=sustain,
#             release=release,
#         )
#         signal = fm_synth.synth_alg1(duracao_amostras, frequencia_base)
        
#         # Escrevendo o áudio em arquivo
#         sf.write(f"dataset/sample_{i}.wav", signal, SAMPLE_RATE)

#     f.write("]")

# %% [markdown]
# ## Lendo o dataset no formato pandas

# %% [markdown]
# ### Lendo as variáveis de entrada

# %%
samples = []
for i in range(tamanho_dataset):
    signal = sf.read(f"dataset/sample_{i}.wav")
    samples.append(signal)

samples = pd.DataFrame(samples)

# %%
samples = samples.drop(columns=[1])
samples.head()
# Out:
#                                                    0
# 0  [0.0, -6.103515625e-05, 6.103515625e-05, 3.051...
# 1  [0.0, -3.0517578125e-05, -3.0517578125e-05, 0....
# 2  [0.0, -6.103515625e-05, 9.1552734375e-05, 0.00...
# 3  [0.0, 0.0, 3.0517578125e-05, 9.1552734375e-05,...
# 4  [0.0, 0.0, 0.0, 0.0, -3.0517578125e-05, -3.051...

# %% [markdown]
# ### Lendo o alvo

# %%
with open("dataset/parameters.json", "r") as f:
    target = f.read()

target = json.loads(target)
target = target[:tamanho_dataset]

target = pd.DataFrame(target)
target.head()
# Out:
#    id  frequencia_base  amplitude1  frequency1  beta2  amplitude2  frequency2  \
# 0   0        15061.183       0.524       0.477  0.344       0.765       0.549
# 1   1        16951.022       0.082       0.350  0.035       0.879       0.471
# 2   2        15429.197       0.736       0.356  0.461       0.279       0.581
# 3   3         1051.543       0.898       0.537  0.633       0.708       0.926
# 4   4         2842.837       0.879       0.063  0.835       0.561       0.806
#
#    beta3  amplitude3  frequency3  ...  frequency4  beta5  amplitude5  \
# 0  0.811       0.439       0.183  ...       0.787  0.739       0.120
# 1  0.787       0.275       0.393  ...       0.697  0.788       0.960
# 2  0.204       0.291       0.803  ...       0.058  0.346       0.573
# 3  0.369       0.107       0.342  ...       0.800  0.849       0.108
# 4  0.412       0.605       0.589  ...       0.528  0.018       0.923
#
#    frequency5  beta_carrier  amplitude_carrier  attack  decay  sustain  \
# 0       0.204         0.147              0.312   0.287  0.127    0.726
# 1       0.593         0.192              0.038   0.701  0.450    0.404
# 2       0.535         0.972              0.612   0.492  0.038    0.472
# 3       0.993         0.133              0.337   0.362  0.150    0.629
# 4       0.378         0.290              0.092   0.882  0.899    0.674
#
#    release
# 0    0.848
# 1    0.560
# 2    0.142
# 3    0.580
# 4    0.224
#
# [5 rows x 22 columns]

# %%
target = target.drop(columns=["id"])
target.head()
# Out:
#    frequencia_base  amplitude1  frequency1  beta2  amplitude2  frequency2  \
# 0        15061.183       0.524       0.477  0.344       0.765       0.549
# 1        16951.022       0.082       0.350  0.035       0.879       0.471
# 2        15429.197       0.736       0.356  0.461       0.279       0.581
# 3         1051.543       0.898       0.537  0.633       0.708       0.926
# 4         2842.837       0.879       0.063  0.835       0.561       0.806
#
#    beta3  amplitude3  frequency3  beta4  ...  frequency4  beta5  amplitude5  \
# 0  0.811       0.439       0.183  0.289  ...       0.787  0.739       0.120
# 1  0.787       0.275       0.393  0.079  ...       0.697  0.788       0.960
# 2  0.204       0.291       0.803  0.414  ...       0.058  0.346       0.573
# 3  0.369       0.107       0.342  0.733  ...       0.800  0.849       0.108
# 4  0.412       0.605       0.589  0.155  ...       0.528  0.018       0.923
#
#    frequency5  beta_carrier  amplitude_carrier  attack  decay  sustain  \
# 0       0.204         0.147              0.312   0.287  0.127    0.726
# 1       0.593         0.192              0.038   0.701  0.450    0.404
# 2       0.535         0.972              0.612   0.492  0.038    0.472
# 3       0.993         0.133              0.337   0.362  0.150    0.629
# 4       0.378         0.290              0.092   0.882  0.899    0.674
#
#    release
# 0    0.848
# 1    0.560
# 2    0.142
# 3    0.580
# 4    0.224
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Juntando alvo e features

# %%
ds = pd.concat([samples, target], axis=1)
ds.head()
# Out:
#                                                    0  frequencia_base  \
# 0  [0.0, -6.103515625e-05, 6.103515625e-05, 3.051...        15061.183
# 1  [0.0, -3.0517578125e-05, -3.0517578125e-05, 0....        16951.022
# 2  [0.0, -6.103515625e-05, 9.1552734375e-05, 0.00...        15429.197
# 3  [0.0, 0.0, 3.0517578125e-05, 9.1552734375e-05,...         1051.543
# 4  [0.0, 0.0, 0.0, 0.0, -3.0517578125e-05, -3.051...         2842.837
#
#    amplitude1  frequency1  beta2  amplitude2  frequency2  beta3  amplitude3  \
# 0       0.524       0.477  0.344       0.765       0.549  0.811       0.439
# 1       0.082       0.350  0.035       0.879       0.471  0.787       0.275
# 2       0.736       0.356  0.461       0.279       0.581  0.204       0.291
# 3       0.898       0.537  0.633       0.708       0.926  0.369       0.107
# 4       0.879       0.063  0.835       0.561       0.806  0.412       0.605
#
#    frequency3  ...  frequency4  beta5  amplitude5  frequency5  beta_carrier  \
# 0       0.183  ...       0.787  0.739       0.120       0.204         0.147
# 1       0.393  ...       0.697  0.788       0.960       0.593         0.192
# 2       0.803  ...       0.058  0.346       0.573       0.535         0.972
# 3       0.342  ...       0.800  0.849       0.108       0.993         0.133
# 4       0.589  ...       0.528  0.018       0.923       0.378         0.290
#
#    amplitude_carrier  attack  decay  sustain  release
# 0              0.312   0.287  0.127    0.726    0.848
# 1              0.038   0.701  0.450    0.404    0.560
# 2              0.612   0.492  0.038    0.472    0.142
# 3              0.337   0.362  0.150    0.629    0.580
# 4              0.092   0.882  0.899    0.674    0.224
#
# [5 rows x 22 columns]

# %%
ds.shape
# Out:
# (1000, 22)

# %% [markdown]
# ## Separando treino e teste

# %%
train = ds.sample(frac=0.75, random_state=0)
test = ds.drop(train.index)

# %%
train.head(5)
# Out:
#                                                      0  frequencia_base  \
# 993  [0.0, 3.0517578125e-05, -0.00018310546875, 0.0...         8817.278
# 859  [0.0, -3.0517578125e-05, -9.1552734375e-05, -6...        19392.466
# 298  [0.0, 3.0517578125e-05, 6.103515625e-05, -0.00...         4415.950
# 553  [0.0, 6.103515625e-05, -3.0517578125e-05, -0.0...         5680.907
# 672  [0.0, 3.0517578125e-05, -0.0001220703125, 9.15...         8129.444
#
#      amplitude1  frequency1  beta2  amplitude2  frequency2  beta3  amplitude3  \
# 993       0.978       0.489  0.501       0.007       0.126  0.196       0.862
# 859       0.514       0.720  0.865       0.681       0.650  0.282       0.877
# 298       0.867       0.971  0.216       0.636       0.788  0.085       0.890
# 553       0.125       0.696  0.770       0.044       0.480  0.299       0.797
# 672       0.047       0.667  0.831       0.748       0.640  0.172       0.429
#
#      frequency3  ...  frequency4  beta5  amplitude5  frequency5  beta_carrier  \
# 993       0.461  ...       0.381  0.931       0.071       0.235         0.166
# 859       0.992  ...       0.565  0.330       0.973       0.234         0.708
# 298       0.498  ...       0.911  0.921       0.125       0.463         0.464
# 553       0.708  ...       0.084  0.451       0.871       0.987         0.038
# 672       0.501  ...       0.893  0.343       0.940       0.310         0.110
#
#      amplitude_carrier  attack  decay  sustain  release
# 993              0.853   0.441  0.810    0.005    0.430
# 859              0.891   0.996  0.504    0.526    0.840
# 298              0.766   0.578  0.664    0.177    0.634
# 553              0.886   0.508  0.090    0.869    0.467
# 672              0.298   0.250  0.279    0.257    0.068
#
# [5 rows x 22 columns]

# %%
x = pd.DataFrame(train[0])
x.head()
# Out:
#                                                      0
# 993  [0.0, 3.0517578125e-05, -0.00018310546875, 0.0...
# 859  [0.0, -3.0517578125e-05, -9.1552734375e-05, -6...
# 298  [0.0, 3.0517578125e-05, 6.103515625e-05, -0.00...
# 553  [0.0, 6.103515625e-05, -3.0517578125e-05, -0.0...
# 672  [0.0, 3.0517578125e-05, -0.0001220703125, 9.15...

# %%
x = np.array(x[0].values.tolist())
x[0]
# Out:
# array([ 0.00000000e+00,  3.05175781e-05, -1.83105469e-04, ...,
#        -3.05175781e-05,  0.00000000e+00, -3.05175781e-05])

# %%
len(x[0])
# Out:
# 88200

# %%
y = train.drop(columns=[0])
y.head()
# Out:
#      frequencia_base  amplitude1  frequency1  beta2  amplitude2  frequency2  \
# 993         8817.278       0.978       0.489  0.501       0.007       0.126
# 859        19392.466       0.514       0.720  0.865       0.681       0.650
# 298         4415.950       0.867       0.971  0.216       0.636       0.788
# 553         5680.907       0.125       0.696  0.770       0.044       0.480
# 672         8129.444       0.047       0.667  0.831       0.748       0.640
#
#      beta3  amplitude3  frequency3  beta4  ...  frequency4  beta5  amplitude5  \
# 993  0.196       0.862       0.461  0.633  ...       0.381  0.931       0.071
# 859  0.282       0.877       0.992  0.890  ...       0.565  0.330       0.973
# 298  0.085       0.890       0.498  0.188  ...       0.911  0.921       0.125
# 553  0.299       0.797       0.708  0.627  ...       0.084  0.451       0.871
# 672  0.172       0.429       0.501  0.348  ...       0.893  0.343       0.940
#
#      frequency5  beta_carrier  amplitude_carrier  attack  decay  sustain  \
# 993       0.235         0.166              0.853   0.441  0.810    0.005
# 859       0.234         0.708              0.891   0.996  0.504    0.526
# 298       0.463         0.464              0.766   0.578  0.664    0.177
# 553       0.987         0.038              0.886   0.508  0.090    0.869
# 672       0.310         0.110              0.298   0.250  0.279    0.257
#
#      release
# 993    0.430
# 859    0.840
# 298    0.634
# 553    0.467
# 672    0.068
#
# [5 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler_y = StandardScaler()
y_train_norm = scaler_y.fit_transform(y)
print(y_train_norm)
# Out:
# [[-0.21232598  1.64669989 -0.02589548 ...  1.12805675 -1.79519097
#   -0.24429463]
#  [ 1.65011155  0.01738405  0.7698462  ...  0.06290214  0.06066991
#    1.16883575]
#  [-0.98746098  1.25692821  1.63448326 ...  0.61984572 -1.18250753
#    0.4588239 ]
#  ...
#  [-1.56460435 -0.05986799  1.44157619 ...  0.30308406 -1.54584306
#   -1.10940615]
#  [-1.04462174 -1.49956518  1.36923603 ... -0.03456299  1.49263934
#   -0.42007426]
#  [-1.01960071 -0.81131969 -0.52194224 ... -1.54875337 -1.31786783
#    0.78625655]]

# %% [markdown]
# ### Quebrando a entrada em frames

# %%
frame_length = 2048

dataset = []
for sample in x:
  length = sample.shape[0]
  num_frames = int(length / frame_length)
  amostras_uteis = num_frames * frame_length
  sample_cutted = sample[:amostras_uteis]
  sample_cutted = sample_cutted.reshape(num_frames, frame_length)
  dataset.append(sample_cutted)

x = np.array(dataset)
print(x.shape)
x[0:5]
# Out:
# (750, 43, 2048)
# array([[[ 0.00000000e+00,  3.05175781e-05, -1.83105469e-04, ...,
#          -1.79412842e-01,  1.44714355e-01, -5.41992188e-02],
#         [-5.79528809e-02,  1.47705078e-01, -1.79779053e-01, ...,
#          -3.36639404e-01,  1.97692871e-01,  1.64184570e-02],
#         [-2.23175049e-01,  3.45520020e-01, -3.38409424e-01, ...,
#          -4.20898438e-01,  1.45080566e-01,  1.87164307e-01],
#         ...,
#         [-1.83105469e-03,  2.71606445e-03, -2.62451172e-03, ...,
#          -1.46484375e-03,  4.27246094e-04,  7.32421875e-04],
#         [-1.64794922e-03,  1.89208984e-03, -1.43432617e-03, ...,
#          -4.88281250e-04, -1.52587891e-04,  6.40869141e-04],
#         [-9.76562500e-04,  8.85009766e-04, -5.18798828e-04, ...,
#          -3.05175781e-05, -3.05175781e-05,  3.05175781e-05]],
#
#        [[ 0.00000000e+00, -3.05175781e-05, -9.15527344e-05, ...,
#           2.22167969e-02,  3.25012207e-02,  5.02929688e-02],
#         [ 7.74536133e-02, -2.73437500e-02, -6.90612793e-02, ...,
#          -1.57043457e-01, -3.83911133e-02,  1.33728027e-01],
#         [ 1.50848389e-01,  1.58477783e-01,  1.49017334e-01, ...,
#          -2.47436523e-01, -2.49145508e-01, -2.47589111e-01],
#         ...,
#         [-1.53869629e-01, -1.55578613e-01, -8.99047852e-02, ...,
#           9.46655273e-02,  9.53674316e-02,  8.15124512e-02],
#         [-2.67639160e-02, -1.05987549e-01, -5.08422852e-02, ...,
#          -1.84936523e-02,  4.23583984e-02,  3.28369141e-02],
#         [ 1.25122070e-03,  1.21459961e-02, -1.59606934e-02, ...,
#          -1.83105469e-04,  4.88281250e-04,  9.76562500e-04]],
#
#        [[ 0.00000000e+00,  3.05175781e-05,  6.10351562e-05, ...,
#          -3.31115723e-02, -1.22894287e-01, -4.24804688e-02],
#         [ 9.67407227e-02,  1.00646973e-01, -4.44030762e-02, ...,
#          -2.37976074e-01, -1.44744873e-01,  1.39648438e-01],
#         [ 2.34039307e-01, -1.61743164e-03, -2.34527588e-01, ...,
#          -2.87506104e-01,  1.33972168e-01,  3.68804932e-01],
#         ...,
#         [ 3.77807617e-02,  5.59387207e-02, -5.58471680e-03, ...,
#          -3.29895020e-02, -3.32336426e-02,  1.29394531e-02],
#         [ 4.10156250e-02,  1.18103027e-02, -3.50646973e-02, ...,
#          -1.95922852e-02,  7.93457031e-04,  2.02026367e-02],
#         [ 1.16577148e-02, -1.34582520e-02, -1.98059082e-02, ...,
#          -3.66210938e-04,  1.12915039e-03,  1.00708008e-03]],
#
#        [[ 0.00000000e+00,  6.10351562e-05, -3.05175781e-05, ...,
#          -1.17767334e-01,  1.18927002e-01,  1.09069824e-01],
#         [-1.22680664e-01, -9.42077637e-02,  1.37817383e-01, ...,
#          -1.07116699e-02, -3.21380615e-01,  6.19812012e-02],
#         [ 3.17474365e-01, -7.22351074e-02, -3.08258057e-01, ...,
#           3.91937256e-01,  2.72949219e-01, -4.25476074e-01],
#         ...,
#         [-4.11102295e-01, -2.23114014e-01,  4.17846680e-01, ...,
#          -7.47375488e-02, -3.07617188e-01,  8.65783691e-02],
#         [ 2.94799805e-01, -1.30950928e-01, -2.87780762e-01, ...,
#           1.46911621e-01,  6.34765625e-02, -1.50604248e-01],
#         [-5.67321777e-02,  1.57623291e-01,  3.32031250e-02, ...,
#          -9.61303711e-03,  4.79125977e-03,  8.78906250e-03]],
#
#        [[ 0.00000000e+00,  3.05175781e-05, -1.22070312e-04, ...,
#          -4.14733887e-02,  1.02905273e-01, -1.02294922e-01],
#         [ 4.66003418e-02,  3.76892090e-02, -1.01867676e-01, ...,
#           8.54492188e-04,  1.55700684e-01, -2.21160889e-01],
#         [ 1.66076660e-01, -1.07116699e-02, -1.60156250e-01, ...,
#           1.09008789e-01,  9.29565430e-02, -2.45727539e-01],
#         ...,
#         [ 3.04565430e-02, -7.14111328e-02,  7.08312988e-02, ...,
#           4.20532227e-02, -7.62634277e-02,  5.52062988e-02],
#         [ 7.93457031e-04, -5.37109375e-02,  7.65380859e-02, ...,
#           1.83715820e-02, -6.87561035e-02,  7.10449219e-02],
#         [-3.03955078e-02, -2.69470215e-02,  6.86340332e-02, ...,
#          -8.23974609e-04, -4.79125977e-03,  6.98852539e-03]]])

# %% [markdown]
# ## Construindo o modelo

# %%
from keras.layers import TimeDistributed, Dense, Input, Lambda, BatchNormalization, Concatenate, Conv1D, ZeroPadding1D, Flatten, Dropout, MaxPooling1D
from keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.callbacks import EarlyStopping
import tensorflow as tf
# Out:
# 2024-12-23 01:11:44.834133: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-23 01:11:44.846243: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1734927104.860308   13612 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1734927104.865064   13612 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-23 01:11:44.879990: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Configurando para não alocar diretamente toda a memória da GPU (alocar conforme necessário)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)  # Aloca memória conforme necessário
    except RuntimeError as e:
        print(e)

# %%
def regressor(input_dims, output_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims/2), activation=activation, use_bias=bias, kernel_regularizer="l2")(input_layer)
  x_0 = Dropout(0.2)(x_0)
  x_2 = Dense(int(input_dims/4), activation=activation, use_bias=bias)(x_0)
  saidas = Dense(output_dims, activation=None, name='regressor_saidas', use_bias=bias)(x_2)

  return Model(input_layer, saidas, name="regressor")

def build_models(input_len, input_dims, output_dims, activation, bias):
  # Camadas de entrada
  input_layer = Input(shape=(input_len, input_dims))

  x_n = BatchNormalization()(input_layer)

  # Features 1
  extrator1 = Conv1D(
    filters=32,
    kernel_size=256,
    strides=2,
    padding="same",
    data_format="channels_first",
    activation='relu',
    input_shape=(input_len, input_dims),
    kernel_regularizer="l2",
    use_bias=True,
  )
  pooling1 = MaxPooling1D(pool_size=2, data_format="channels_first")

  features1 = extrator1(x_n)
  features1 = pooling1(features1)


  extrator1_2 = Conv1D(
    filters=16,
    kernel_size=128,
    strides=1,
    # padding="same",
    data_format="channels_first",
    activation='relu',
    input_shape=(input_len, input_dims),
    kernel_regularizer="l2",
    use_bias=True,
  )
  pooling1_2 = MaxPooling1D(pool_size=2, data_format="channels_first")

  features1_2 = extrator1_2(features1)
  features1_2 = pooling1_2(features1_2)

  features_flatten1_2 = Flatten()(features1_2)

  # Features 2
  extrator2 = Conv1D(
    filters=32,
    kernel_size=128,
    strides=1,
    # padding="causal",
    data_format="channels_first",
    activation='relu',
    input_shape=(input_len, input_dims),
    kernel_regularizer="l2",
    use_bias=True,
  )
  pooling2 = MaxPooling1D(pool_size=2, data_format="channels_first")

  features2 = extrator2(x_n)
  features2 = pooling2(features2)


  extrator2_2 = Conv1D(
    filters=16,
    kernel_size=32,
    strides=1,
    # padding="same",
    data_format="channels_first",
    activation='relu',
    input_shape=(input_len, input_dims),
    kernel_regularizer="l2",
    use_bias=True,
  )
  pooling2_2 = MaxPooling1D(pool_size=2, data_format="channels_first")

  features2_2 = extrator2_2(features2)
  features2_2 = pooling2_2(features2_2)

  features_flatten2_2 = Flatten()(features2_2)

  # Concatenando as features
  features_flatten = Concatenate()([features_flatten1_2, features_flatten2_2])

  # Regrssão
  regressao = regressor(features_flatten.shape[1], output_dims, activation, bias)

  saida = regressao(features_flatten)
  
  return (
      Model(input_layer, saida, name="regressao"),
      Model(input_layer, features_flatten, name="projecao")
  )

model, features = build_models(x.shape[1], x.shape[2], y_train_norm.shape[1], 'relu', False)
model.compile(optimizer='adamax', loss='mse', metrics=['mae', 'mse', 'mean_absolute_percentage_error'])
plot_model(model, show_shapes=True, expand_nested=True)
# Out:
# /home/sergiosilva/@pessoal/fmsynth/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Callback para recuperar o melhor peso, e parar quando ficar três épocas sem melhora
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# Treinando o modelo
history = model.fit(x, y_train_norm, epochs=30, validation_split = 0.2, callbacks=[callback])
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734927177.056709   13697 service.cc:148] XLA service 0x7442c0021ee0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734927177.056818   13697 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2024-12-23 01:12:57.110482: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1734927177.261284   13697 cuda_dnn.cc:529] Loaded cuDNN version 90501
# 2024-12-23 01:12:57.463070: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.36GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-23 01:12:58.098290: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# I0000 00:00:1734927184.192159   13697 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 17/19 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 417.6666 - mae: 5.5050 - mean_absolute_percentage_error: 1961.1056 - mse: 349.8943
# 2024-12-23 01:13:06.796264: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-23 01:13:07.313206: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 984.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - loss: 401.4412 - mae: 5.4043 - mean_absolute_percentage_error: 1922.1104 - mse: 342.2594
# 2024-12-23 01:13:13.306579: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.36GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-23 01:13:13.786225: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-23 01:13:14.591888: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 962.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-23 01:13:14.955297: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 903.34MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 655ms/step - loss: 394.0832 - mae: 5.3108 - mean_absolute_percentage_error: 1885.9004 - mse: 335.1697 - val_loss: 40.8372 - val_mae: 0.8575 - val_mean_absolute_percentage_error: 101.7949 - val_mse: 0.9833
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 38.8870 - mae: 0.8638 - mean_absolute_percentage_error: 148.1866 - mse: 1.0148 - val_loss: 34.7475 - val_mae: 0.8581 - val_mean_absolute_percentage_error: 101.8857 - val_mse: 0.9848
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 33.8883 - mae: 0.8658 - mean_absolute_percentage_error: 118.5627 - mse: 1.0225 - val_loss: 31.8191 - val_mae: 0.8583 - val_mean_absolute_percentage_error: 103.5296 - val_mse: 0.9849
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 31.3016 - mae: 0.8632 - mean_absolute_percentage_error: 129.6265 - mse: 1.0308 - val_loss: 29.9373 - val_mae: 0.8576 - val_mean_absolute_percentage_error: 101.6460 - val_mse: 0.9846
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 29.5753 - mae: 0.8488 - mean_absolute_percentage_error: 117.7503 - mse: 0.9841 - val_loss: 28.5878 - val_mae: 0.8583 - val_mean_absolute_percentage_error: 103.0216 - val_mse: 0.9854
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 28.2712 - mae: 0.8440 - mean_absolute_percentage_error: 123.9171 - mse: 0.9664 - val_loss: 27.5426 - val_mae: 0.8576 - val_mean_absolute_percentage_error: 101.7235 - val_mse: 0.9849
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 27.2896 - mae: 0.8443 - mean_absolute_percentage_error: 125.0065 - mse: 0.9659 - val_loss: 26.6957 - val_mae: 0.8577 - val_mean_absolute_percentage_error: 104.8704 - val_mse: 0.9845
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 26.4751 - mae: 0.8361 - mean_absolute_percentage_error: 120.0810 - mse: 0.9527 - val_loss: 25.9897 - val_mae: 0.8582 - val_mean_absolute_percentage_error: 105.6666 - val_mse: 0.9866
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 25.7791 - mae: 0.8387 - mean_absolute_percentage_error: 137.5162 - mse: 0.9582 - val_loss: 25.3851 - val_mae: 0.8588 - val_mean_absolute_percentage_error: 107.6663 - val_mse: 0.9883
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 25.2138 - mae: 0.8354 - mean_absolute_percentage_error: 123.7887 - mse: 0.9568 - val_loss: 24.8552 - val_mae: 0.8587 - val_mean_absolute_percentage_error: 107.0965 - val_mse: 0.9886
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 24.6806 - mae: 0.8300 - mean_absolute_percentage_error: 143.7193 - mse: 0.9448 - val_loss: 24.3744 - val_mae: 0.8567 - val_mean_absolute_percentage_error: 107.8714 - val_mse: 0.9841
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 24.1977 - mae: 0.8221 - mean_absolute_percentage_error: 141.6468 - mse: 0.9221 - val_loss: 23.9471 - val_mae: 0.8580 - val_mean_absolute_percentage_error: 108.3286 - val_mse: 0.9861
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 23.7935 - mae: 0.8247 - mean_absolute_percentage_error: 125.7862 - mse: 0.9356 - val_loss: 23.5588 - val_mae: 0.8576 - val_mean_absolute_percentage_error: 110.9753 - val_mse: 0.9857
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 23.3969 - mae: 0.8159 - mean_absolute_percentage_error: 126.3120 - mse: 0.9279 - val_loss: 23.2070 - val_mae: 0.8594 - val_mean_absolute_percentage_error: 111.0601 - val_mse: 0.9918
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 23.0375 - mae: 0.8091 - mean_absolute_percentage_error: 143.8604 - mse: 0.9046 - val_loss: 22.8776 - val_mae: 0.8603 - val_mean_absolute_percentage_error: 116.1561 - val_mse: 0.9943
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 22.7356 - mae: 0.8129 - mean_absolute_percentage_error: 141.6230 - mse: 0.9293 - val_loss: 22.5711 - val_mae: 0.8597 - val_mean_absolute_percentage_error: 116.2617 - val_mse: 0.9940
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 22.3953 - mae: 0.8011 - mean_absolute_percentage_error: 135.2015 - mse: 0.8959 - val_loss: 22.2794 - val_mae: 0.8619 - val_mean_absolute_percentage_error: 120.3261 - val_mse: 0.9964
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 22.0822 - mae: 0.7909 - mean_absolute_percentage_error: 129.6026 - mse: 0.8741 - val_loss: 22.0010 - val_mae: 0.8602 - val_mean_absolute_percentage_error: 119.7214 - val_mse: 0.9963
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 21.7992 - mae: 0.7852 - mean_absolute_percentage_error: 125.3661 - mse: 0.8690 - val_loss: 21.7360 - val_mae: 0.8597 - val_mean_absolute_percentage_error: 118.5212 - val_mse: 0.9939
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 21.5596 - mae: 0.7852 - mean_absolute_percentage_error: 144.4792 - mse: 0.8768 - val_loss: 21.4985 - val_mae: 0.8638 - val_mean_absolute_percentage_error: 125.6505 - val_mse: 1.0046
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 21.2548 - mae: 0.7691 - mean_absolute_percentage_error: 115.1109 - mse: 0.8204 - val_loss: 21.2523 - val_mae: 0.8602 - val_mean_absolute_percentage_error: 124.5831 - val_mse: 0.9988
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 21.0129 - mae: 0.7632 - mean_absolute_percentage_error: 128.0524 - mse: 0.8156 - val_loss: 21.0273 - val_mae: 0.8619 - val_mean_absolute_percentage_error: 124.0460 - val_mse: 1.0044
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 20.7950 - mae: 0.7696 - mean_absolute_percentage_error: 144.5393 - mse: 0.8321 - val_loss: 20.8310 - val_mae: 0.8690 - val_mean_absolute_percentage_error: 126.5339 - val_mse: 1.0279
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 20.6160 - mae: 0.7594 - mean_absolute_percentage_error: 142.9007 - mse: 0.8664 - val_loss: 20.5976 - val_mae: 0.8630 - val_mean_absolute_percentage_error: 117.1122 - val_mse: 1.0064
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 20.3360 - mae: 0.7491 - mean_absolute_percentage_error: 127.6580 - mse: 0.7993 - val_loss: 20.3864 - val_mae: 0.8631 - val_mean_absolute_percentage_error: 131.2960 - val_mse: 1.0046
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 20.0874 - mae: 0.7250 - mean_absolute_percentage_error: 131.5535 - mse: 0.7531 - val_loss: 20.2021 - val_mae: 0.8697 - val_mean_absolute_percentage_error: 125.2885 - val_mse: 1.0229
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 19.8766 - mae: 0.7223 - mean_absolute_percentage_error: 137.3631 - mse: 0.7478 - val_loss: 20.0046 - val_mae: 0.8677 - val_mean_absolute_percentage_error: 134.0679 - val_mse: 1.0217
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 19.6983 - mae: 0.7291 - mean_absolute_percentage_error: 126.5978 - mse: 0.7655 - val_loss: 19.8049 - val_mae: 0.8660 - val_mean_absolute_percentage_error: 136.0999 - val_mse: 1.0138
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 19.4897 - mae: 0.7187 - mean_absolute_percentage_error: 115.2213 - mse: 0.7428 - val_loss: 19.6274 - val_mae: 0.8688 - val_mean_absolute_percentage_error: 133.4246 - val_mse: 1.0213
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 19.2833 - mae: 0.7083 - mean_absolute_percentage_error: 131.8913 - mse: 0.7258 - val_loss: 19.4382 - val_mae: 0.8659 - val_mean_absolute_percentage_error: 131.6871 - val_mse: 1.0141

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae  mean_absolute_percentage_error       mse   val_loss  \
# 25  22.189154  0.717946                      152.483978  0.738961  22.370466
# 26  21.923225  0.709452                      156.925690  0.723937  22.117012
# 27  21.676170  0.707677                      155.123428  0.722695  21.869005
# 28  21.418255  0.697595                      162.093887  0.704726  21.630596
# 29  21.180170  0.693393                      148.261459  0.698403  21.400291
#
#      val_mae  val_mean_absolute_percentage_error   val_mse  epoch
# 25  0.880135                          144.806915  1.054722     25
# 26  0.872232                          137.354477  1.050568     26
# 27  0.871110                          136.872375  1.043724     27
# 28  0.869769                          131.310181  1.042415     28
# 29  0.869164                          140.736252  1.040365     29

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

plt.figure()
plt.title("Evolução das funções de perda durante o treinamento da rede")
plt.xlabel('Rodada')
plt.ylabel('Mean Square Error')
plt.plot(hist['epoch'], hist['mse'], label='MSE Treino')
plt.plot(hist['epoch'], hist['val_mse'], label = 'MSE Validação')
plt.legend()

plt.figure()
plt.xlabel('Rodada')
plt.ylabel('Mean Absolute Error')
plt.plot(hist['epoch'], hist['mae'], label='MAE Treino')
plt.plot(hist['epoch'], hist['val_mae'], label = 'MAE Validação')
plt.legend()

plt.show()
